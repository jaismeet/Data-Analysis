# %%
import mysql.connector as my

con = my.connect(
    host = "localhost",
    user = "root",
    password = "131313",
    database = "ecommerce"
)

cr = con.cursor()

cr.execute('''CREATE TABLE customer (
customer_id varchar(10) NOT NULL,
name varchar(100) NOT NULL,
city varchar(65) NOT NULL,
email varchar(45) NOT NULL,
phone_no varchar(15) NOT NULL,
address varchar(100) NOT NULL,
pin_code int NOT NULL,
PRIMARY KEY (customer_id));'''
)
con.commit()

print("Customer table created successfully..")
# Out:
# Customer table created successfully..

# %%
cr.execute('''INSERT INTO customer (customer_id, name, city, email, phone_no, address, pin_code) VALUES
('CUST001', 'Alice Johnson', 'New York', 'alice.johnson@example.com', '123-456-7890', '123 Elm St', 10001),
('CUST002', 'Bob Smith', 'Los Angeles', 'bob.smith@example.com', '234-567-8901', '456 Oak St', 90001),
('CUST003', 'Carol Davis', 'Chicago', 'carol.davis@example.com', '345-678-9012', '789 Pine St', 60601),
('CUST004', 'David Brown', 'Houston', 'david.brown@example.com', '456-789-0123', '101 Maple St', 77001),
('CUST005', 'Eva Green', 'Phoenix', 'eva.green@example.com', '567-890-1234', '202 Birch St', 85001),
('CUST006', 'Frank White', 'Philadelphia', 'frank.white@example.com', '678-901-2345', '303 Cedar St', 19101),
('CUST007', 'Grace Wilson', 'San Antonio', 'grace.wilson@example.com', '789-012-3456', '404 Walnut St', 78201),
('CUST008', 'Henry Lee', 'San Diego', 'henry.lee@example.com', '890-123-4567', '505 Fir St', 92101),
('CUST009', 'Ivy Martinez', 'Dallas', 'ivy.martinez@example.com', '901-234-5678', '606 Spruce St', 75201),
('CUST010', 'Jack Taylor', 'San Jose', 'jack.taylor@example.com', '012-345-6789', '707 Poplar St', 95101),
('CUST011', 'Karen Anderson', 'Austin', 'karen.anderson@example.com', '123-456-7891', '808 Maple St', 73301),
('CUST012', 'Larry Thomas', 'Jacksonville', 'larry.thomas@example.com', '234-567-8902', '909 Oak St', 32201),
('CUST013', 'Mia Harris', 'San Francisco', 'mia.harris@example.com', '345-678-9013', '101 Pine St', 94101),
('CUST014', 'Nathan Clark', 'Columbus', 'nathan.clark@example.com', '456-789-0124', '202 Elm St', 43201),
('CUST015', 'Olivia Lewis', 'Indianapolis', 'olivia.lewis@example.com', '567-890-1235', '303 Cedar St', 46201),
('CUST016', 'Paul Walker', 'Charlotte', 'paul.walker@example.com', '678-901-2346', '404 Fir St', 28201),
('CUST017', 'Quincy Allen', 'Seattle', 'quincy.allen@example.com', '789-012-3457', '505 Spruce St', 98101),
('CUST018', 'Rachel Young', 'Denver', 'rachel.young@example.com', '890-123-4568', '606 Poplar St', 80201),
('CUST019', 'Steve King', 'Washington', 'steve.king@example.com', '901-234-5679', '707 Pine St', 20001),
('CUST020', 'Tina Wright', 'Boston', 'tina.wright@example.com', '012-345-6780', '808 Oak St', 02101)''')

con.commit()

print("Data Inserted Successfully..")
# Out:
# Data Inserted Successfully..

# %%
cr.execute('''update customer set city = 'New York' where customer_id in ('CUST008','CUST009','CUST010')''')
cr.execute('''update customer set city = 'Los Angeles' where customer_id in ('CUST011','CUST012')''')
cr.execute('''update customer set city = 'Chicago' where customer_id in ('CUST013','CUST014','CUST015','CUST016')''')
cr.execute('''update customer set city = 'Houston' where customer_id in ('CUST017','CUST018','CUST019')''')
cr.execute('''update customer set city = 'Phoenix' where customer_id in ('CUST020')''')

con.commit()
print("Data Updated Successfully..")
# Out:
# Data Updated Successfully..

# %%
cr.execute("""CREATE TABLE product (
`product_id` varchar(10) NOT NULL,
`product_name` varchar(100) NOT NULL,
`category` varchar(65) NOT NULL,
`sub_category` varchar(45) NOT NULL,
`original_price` double NOT NULL,
`selling_price` double NOT NULL,
`stock` int NOT NULL,
PRIMARY KEY (`product_id`)
)""")
con.commit()

print("Product table created successfully..")
# Out:
# Product table created successfully..

# %%
cr.execute('''INSERT INTO product (product_id, product_name, category, sub_category, original_price, selling_price, stock) VALUES
('PROD001', 'Laptop', 'Electronics', 'Computers', 1200.00, 1100.00, 15),
('PROD002', 'Smartphone', 'Electronics', 'Mobile Phones', 800.00, 750.00, 30),
('PROD003', 'Headphones', 'Electronics', 'Audio', 150.00, 130.00, 50),
('PROD004', 'Washing Machine', 'Home Appliances', 'Laundry', 700.00, 650.00, 10),
('PROD005', 'Refrigerator', 'Home Appliances', 'Cooling', 1200.00, 1100.00, 8),
('PROD006', 'Microwave Oven', 'Home Appliances', 'Cooking', 200.00, 180.00, 20),
('PROD007', 'Dining Table', 'Furniture', 'Tables', 300.00, 280.00, 12),
('PROD008', 'Sofa', 'Furniture', 'Seating', 600.00, 550.00, 5),
('PROD009', 'Office Chair', 'Furniture', 'Seating', 150.00, 130.00, 25),
('PROD010', 'LED TV', 'Electronics', 'Televisions', 500.00, 450.00, 18),
('PROD011', 'Blender', 'Home Appliances', 'Kitchen', 100.00, 90.00, 22),
('PROD012', 'Electric Kettle', 'Home Appliances', 'Kitchen', 60.00, 55.00, 35),
('PROD013', 'Coffee Maker', 'Home Appliances', 'Kitchen', 120.00, 110.00, 15),
('PROD014', 'Desk Lamp', 'Furniture', 'Lighting', 40.00, 35.00, 30),
('PROD015', 'Bookshelf', 'Furniture', 'Storage', 200.00, 180.00, 8),
('PROD016', 'Air Conditioner', 'Home Appliances', 'Cooling', 900.00, 850.00, 7),
('PROD017', 'Smartwatch', 'Electronics', 'Wearables', 250.00, 230.00, 40),
('PROD018', 'Camera', 'Electronics', 'Photography', 700.00, 650.00, 12),
('PROD019', 'Yoga Mat', 'Sports & Outdoors', 'Fitness', 30.00, 25.00, 50),
('PROD020', 'Treadmill', 'Sports & Outdoors', 'Fitness', 800.00, 750.00, 6)
''')
con.commit()

print("Data Inserted Successfully..")
# Out:
# Data Inserted Successfully..

# %%
cr.execute("""CREATE TABLE order_details (
order_id int NOT NULL AUTO_INCREMENT,
customer_id varchar(10) NOT NULL,
product_id varchar(10) NOT NULL,
quantity double NOT NULL,
total_price double NOT NULL,
payment_mode varchar(60) NOT NULL,
order_date datetime DEFAULT NULL,
order_status varchar(20) NOT NULL,
PRIMARY KEY (order_id),
KEY customer_id (customer_id),
KEY product_id (product_id),
CONSTRAINT order_details_ibfk_1 FOREIGN KEY (customer_id)
REFERENCES customer (customer_id),
CONSTRAINT order_details_ibfk_2 FOREIGN KEY (product_id)
REFERENCES product (product_id)
)""")
con.commit()

print("Order_details table created successfully..")
# Out:
# Order_details table created successfully..

# %%
cr.execute('''INSERT INTO order_details (customer_id, product_id, quantity, total_price, payment_mode, order_date, order_status) VALUES
('CUST001', 'PROD001', 1, 1100.00, 'Credit Card', '2024-08-01 10:00:00', 'Shipped'),
('CUST002', 'PROD002', 2, 1500.00, 'PayPal', '2024-08-02 11:30:00', 'Delivered'),
('CUST003', 'PROD003', 1, 130.00, 'Credit Card', '2024-08-03 09:15:00', 'Pending'),
('CUST004', 'PROD004', 1, 650.00, 'Debit Card', '2024-08-04 14:45:00', 'Cancelled'),
('CUST005', 'PROD005', 1, 1100.00, 'Credit Card', '2024-08-05 08:00:00', 'Shipped'),
('CUST006', 'PROD006', 3, 540.00, 'PayPal', '2024-08-06 16:30:00', 'Delivered'),
('CUST007', 'PROD007', 1, 280.00, 'Credit Card', '2024-08-07 10:00:00', 'Shipped'),
('CUST008', 'PROD008', 1, 550.00, 'Debit Card', '2024-08-08 11:00:00', 'Pending'),
('CUST009', 'PROD009', 2, 260.00, 'Credit Card', '2024-08-09 12:00:00', 'Delivered'),
('CUST010', 'PROD010', 1, 450.00, 'PayPal', '2024-08-10 13:00:00', 'Shipped'),
('CUST011', 'PROD011', 2, 180.00, 'Credit Card', '2024-08-11 14:00:00', 'Pending'),
('CUST012', 'PROD012', 1, 55.00, 'Debit Card', '2024-08-12 15:00:00', 'Delivered'),
('CUST013', 'PROD013', 1, 110.00, 'PayPal', '2024-08-13 16:00:00', 'Shipped'),
('CUST014', 'PROD014', 1, 35.00, 'Credit Card', '2024-08-14 17:00:00', 'Delivered'),
('CUST015', 'PROD015', 1, 180.00, 'Debit Card', '2024-08-15 18:00:00', 'Shipped'),
('CUST016', 'PROD016', 1, 850.00, 'Credit Card', '2024-08-16 19:00:00', 'Pending'),
('CUST017', 'PROD017', 1, 230.00, 'PayPal', '2024-08-17 20:00:00', 'Delivered'),
('CUST018', 'PROD018', 1, 650.00, 'Credit Card', '2024-08-18 21:00:00', 'Shipped'),
('CUST019', 'PROD019', 2, 50.00, 'Debit Card', '2024-08-19 22:00:00', 'Pending'),
('CUST020', 'PROD020', 1, 750.00, 'Credit Card', '2024-08-20 23:00:00', 'Delivered')
''')
con.commit()

print("Data Inserted Successfully..")
# Out:
# Data Inserted Successfully..

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

# Query data from the 'customer' table
cr.execute('SELECT * FROM customer')
#After fetching data from the database we are storing it into Pandas DataFrame
customer_data = pd.DataFrame(cr.fetchall(), columns=[desc[0] for desc in
cr.description])
# Query data from the 'product' table
cr.execute('SELECT * FROM product')
product_data = pd.DataFrame(cr.fetchall(), columns=[desc[0] for desc in
cr.description])
# Query data from the 'order_details' table
cr.execute('SELECT * FROM order_details')
order_data = pd.DataFrame(cr.fetchall(), columns=[desc[0] for desc in
cr.description])

# %%
#printing first 5 records for customer_data from table
customer_data.head()
# Out:
#   customer_id           name         city                      email  \
# 0     CUST001  Alice Johnson     New York  alice.johnson@example.com
# 1     CUST002      Bob Smith  Los Angeles      bob.smith@example.com
# 2     CUST003    Carol Davis      Chicago    carol.davis@example.com
# 3     CUST004    David Brown      Houston    david.brown@example.com
# 4     CUST005      Eva Green      Phoenix      eva.green@example.com
#
#        phone_no       address  pin_code
# 0  123-456-7890    123 Elm St     10001
# 1  234-567-8901    456 Oak St     90001
# 2  345-678-9012   789 Pine St     60601
# 3  456-789-0123  101 Maple St     77001
# 4  567-890-1234  202 Birch St     85001

# %%
#printing first 5 records for product_data from each table
product_data.head()
# Out:
#   product_id     product_name         category   sub_category  original_price  \
# 0    PROD001           Laptop      Electronics      Computers          1200.0
# 1    PROD002       Smartphone      Electronics  Mobile Phones           800.0
# 2    PROD003       Headphones      Electronics          Audio           150.0
# 3    PROD004  Washing Machine  Home Appliances        Laundry           700.0
# 4    PROD005     Refrigerator  Home Appliances        Cooling          1200.0
#
#    selling_price  stock
# 0         1100.0     15
# 1          750.0     30
# 2          130.0     50
# 3          650.0     10
# 4         1100.0      8

# %%
#printing first 5 records for order_data from each table
order_data.head()
# Out:
#    order_id customer_id product_id  quantity  total_price payment_mode  \
# 0         1     CUST001    PROD001       1.0       1100.0  Credit Card
# 1         2     CUST002    PROD002       2.0       1500.0       PayPal
# 2         3     CUST003    PROD003       1.0        130.0  Credit Card
# 3         4     CUST004    PROD004       1.0        650.0   Debit Card
# 4         5     CUST005    PROD005       1.0       1100.0  Credit Card
#
#            order_date order_status
# 0 2024-08-01 10:00:00      Shipped
# 1 2024-08-02 11:30:00    Delivered
# 2 2024-08-03 09:15:00      Pending
# 3 2024-08-04 14:45:00    Cancelled
# 4 2024-08-05 08:00:00      Shipped

# %%
#printing last 5 records for customer_data from each table
customer_data.tail()
# Out:
#    customer_id          name     city                     email      phone_no  \
# 15     CUST016   Paul Walker  Chicago   paul.walker@example.com  678-901-2346
# 16     CUST017  Quincy Allen  Houston  quincy.allen@example.com  789-012-3457
# 17     CUST018  Rachel Young  Houston  rachel.young@example.com  890-123-4568
# 18     CUST019    Steve King  Houston    steve.king@example.com  901-234-5679
# 19     CUST020   Tina Wright  Phoenix   tina.wright@example.com  012-345-6780
#
#           address  pin_code
# 15     404 Fir St     28201
# 16  505 Spruce St     98101
# 17  606 Poplar St     80201
# 18    707 Pine St     20001
# 19     808 Oak St      2101

# %%
#printing last 5 records for product_data from each table
product_data.tail()
# Out:
#    product_id     product_name           category sub_category  \
# 15    PROD016  Air Conditioner    Home Appliances      Cooling
# 16    PROD017       Smartwatch        Electronics    Wearables
# 17    PROD018           Camera        Electronics  Photography
# 18    PROD019         Yoga Mat  Sports & Outdoors      Fitness
# 19    PROD020        Treadmill  Sports & Outdoors      Fitness
#
#     original_price  selling_price  stock
# 15           900.0          850.0      7
# 16           250.0          230.0     40
# 17           700.0          650.0     12
# 18            30.0           25.0     50
# 19           800.0          750.0      6

# %%
#printing last 5 records for order_data from each table
order_data.tail()
# Out:
#     order_id customer_id product_id  quantity  total_price payment_mode  \
# 15        16     CUST016    PROD016       1.0        850.0  Credit Card
# 16        17     CUST017    PROD017       1.0        230.0       PayPal
# 17        18     CUST018    PROD018       1.0        650.0  Credit Card
# 18        19     CUST019    PROD019       2.0         50.0   Debit Card
# 19        20     CUST020    PROD020       1.0        750.0  Credit Card
#
#             order_date order_status
# 15 2024-08-16 19:00:00      Pending
# 16 2024-08-17 20:00:00    Delivered
# 17 2024-08-18 21:00:00      Shipped
# 18 2024-08-19 22:00:00      Pending
# 19 2024-08-20 23:00:00    Delivered

# %%
# display basic information about the customer data
print(customer_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  20 non-null     object
#  1   name         20 non-null     object
#  2   city         20 non-null     object
#  3   email        20 non-null     object
#  4   phone_no     20 non-null     object
#  5   address      20 non-null     object
#  6   pin_code     20 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB
# None

# %%
# display basic information about the product data
print(product_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      20 non-null     object
#  1   product_name    20 non-null     object
#  2   category        20 non-null     object
#  3   sub_category    20 non-null     object
#  4   original_price  20 non-null     float64
#  5   selling_price   20 non-null     float64
#  6   stock           20 non-null     int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.2+ KB
# None

# %%
# display basic information about the order data
print(order_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      20 non-null     int64
#  1   customer_id   20 non-null     object
#  2   product_id    20 non-null     object
#  3   quantity      20 non-null     float64
#  4   total_price   20 non-null     float64
#  5   payment_mode  20 non-null     object
#  6   order_date    20 non-null     datetime64[ns]
#  7   order_status  20 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 1.4+ KB
# None

# %%
# display basic statistics about customer data
print("Basic Statistics About customer_data : \n",customer_data.describe())

# display basic statistics about product data
print("Basic Statistics About product_data : \n",product_data.describe())

# display basic statistics about customer data
print("Basic Statistics About order_data : \n",order_data.describe())
# Out:
# Basic Statistics About customer_data :
#             pin_code
# count     20.000000
# mean   59996.000000
# std    31805.651186
# min     2101.000000
# 25%    31201.000000
# 50%    74251.000000
# 75%    86251.000000
# max    98101.000000
# Basic Statistics About product_data :
#         original_price  selling_price      stock
# count        20.00000      20.000000  20.000000
# mean        450.00000     414.750000  20.900000
# std         385.11789     357.779979  14.138041
# min          30.00000      25.000000   5.000000
# 25%         142.50000     125.000000   9.500000
# 50%         275.00000     255.000000  16.500000
# 75%         725.00000     675.000000  30.000000
# max        1200.00000    1100.000000  50.000000
# Basic Statistics About order_data :
#         order_id   quantity  total_price           order_date
# count  20.00000  20.000000    20.000000                   20
# mean   10.50000   1.300000   482.500000  2024-08-11 03:03:00
# ...

# %%
# check for null values in data
print(customer_data.isna().sum())
print("\n")
print(product_data.isna().sum())
print("\n")
print(order_data.isna().sum())
# Out:
# customer_id    0
# name           0
# city           0
# email          0
# phone_no       0
# address        0
# pin_code       0
# dtype: int64
#
#
# product_id        0
# product_name      0
# category          0
# sub_category      0
# original_price    0
# selling_price     0
# stock             0
# dtype: int64
#
#
# order_id        0
# customer_id     0
# product_id      0
# quantity        0
# total_price     0
# payment_mode    0
# order_date      0
# order_status    0
# dtype: int64

# %%
# if any null value exists in the data 

# print(customer_data.dropna())
# print(product_data.dropna())
# print(order_data.dropna())

# %%
# check for duplicate values
print("In Customer data:",customer_data.duplicated().any())
print("\n")
print("In product data:",product_data.duplicated().any())
print("\n")
print("In Order data:",order_data.duplicated().any())
# Out:
# In Customer data: False
#
#
# In product data: False
#
#
# In Order data: False

# %%
# print(customer_data.drop_duplicates())
# print(product_data.drop_duplicates())
# print(order_data.drop_duplicates())

# %%
# Aggregate the number of customers by city
city_counts = customer_data['city'].value_counts()
city_counts
# Out:
# city
# Chicago         5
# New York        4
# Houston         4
# Los Angeles     3
# Phoenix         2
# Philadelphia    1
# San Antonio     1
# Name: count, dtype: int64

# %%
# Create and display a bar graph
plt.figure(figsize=(10, 6))
city_counts.plot(kind='bar', color='lightsalmon')
plt.title('Total Number of Customers by City')
plt.xlabel('City')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Count orders per customer
order_counts = order_data['customer_id'].value_counts()

# Convert to DataFrame for better readability
order_counts_df = order_counts.reset_index()
order_counts_df.columns = ['customer_id', 'number_of_orders']

# Merge with customer data to get names
customer_orders_df = pd.merge(order_counts_df, customer_data, on='customer_id')

# Sort by number of orders in descending order
customer_orders_df = customer_orders_df.sort_values(by='number_of_orders', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(customer_orders_df['name'], customer_orders_df['number_of_orders'], color='lightblue')
plt.title('Most Frequent Customers by Number of Orders')
plt.xlabel('Customer Name')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Count products per category
category_counts = product_data['category'].value_counts()

# Convert to DataFrame for better readability
category_counts_df = category_counts.reset_index()
category_counts_df.columns = ['Category', 'Number of Products']

# Plotting the bar chart
plt.figure(figsize=(7, 4))
plt.bar(category_counts_df['Category'], category_counts_df['Number of Products'], color='lightpink')
plt.title('Total Number of Products by Category')
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Count the number of products per sub-category
sub_category_counts = product_data['sub_category'].value_counts()

# Convert to DataFrame for better readability
sub_category_counts_df = sub_category_counts.reset_index()
sub_category_counts_df.columns = ['Sub-Category', 'Number of Products']

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(sub_category_counts_df['Sub-Category'], sub_category_counts_df['Number of Products'], color='lightcoral')
plt.title('Distribution of Products Across Sub-Categories')
plt.xlabel('Sub-Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Define the low stock threshold
low_stock_threshold = 10

# Query to fetch all product data
query = 'SELECT product_name, stock FROM product'

# Close the database connection
con.close()

# Filter products with stock levels below or equal to the threshold
low_stock_products = product_data[product_data['stock'] <= low_stock_threshold]

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(low_stock_products['product_name'], low_stock_products['stock'], color='lightblue')
plt.title('Products with Low Stock Levels')
plt.xlabel('Product Name')
plt.ylabel('Stock Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Calculate statistics
average_price = product_data['selling_price'].mean()
max_price = product_data['selling_price'].max()
min_price = product_data['selling_price'].min()

# Prepare data for the bar graph
statistics = {
    'Average Price': average_price,
    'Maximum Price': max_price,
    'Minimum Price': min_price
}

# Create and display a bar graph
plt.figure(figsize=(7, 4))
plt.bar(statistics.keys(), statistics.values(), color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Average , Maximum , Minimum Prices of Product')
plt.xlabel('Price Type')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
cr = con.cursor()
# Query data from the 'product' table to get product names
cr.execute('SELECT product_id, product_name FROM product')
product_names = pd.DataFrame(cr.fetchall(), columns=['product_id', 'product_name'])

# Merge the order data with product names
order_data = order_data.merge(product_names, on='product_id')

# Calculate total quantity ordered by each product
product_quantity = order_data.groupby('product_name').agg({'quantity': 'sum'}).reset_index()

# Sort the products by total quantity in descending order and get the top 10
top_10_products = product_quantity.sort_values(by='quantity', ascending=False).head(10)

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(top_10_products['product_name'], top_10_products['quantity'], color='cornflowerblue')
plt.title('Top 10 Products by Total Order Quantity')
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Ordered')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()

# Display the chart
plt.show()

# Display the top 10 products
print(top_10_products)
# Out:
#        product_name  quantity
# 11   Microwave Oven       3.0
# 1           Blender       2.0
# 19         Yoga Mat       2.0
# 14       Smartphone       2.0
# 12     Office Chair       2.0
# 3            Camera       1.0
# 0   Air Conditioner       1.0
# 2         Bookshelf       1.0
# 7   Electric Kettle       1.0
# 4      Coffee Maker       1.0

# %%
status_counts = order_data['order_status'].value_counts()
print(status_counts)

# Plotting
status_counts.plot(kind='pie', figsize=(10, 7), autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])#['lightpink','skyblue','palegreen','peach']
plt.title('Order Status Distribution')
plt.ylabel('')
plt.show()
# Out:
# order_status
# Shipped      7
# Delivered    7
# Pending      5
# Cancelled    1
# Name: count, dtype: int64

# %%
popular_products = order_data.groupby('product_name').agg({'quantity': 'sum'}).reset_index()
popular_products = popular_products.sort_values(by='quantity', ascending=False).head(10)
print(popular_products)

# Plotting
popular_products.plot(kind='barh', figsize=(10, 6), color = 'lightpink')
plt.title('Top 10 Most Popular Products by Quantity')
plt.ylabel('')
plt.show()
# Out:
#        product_name  quantity
# 11   Microwave Oven       3.0
# 1           Blender       2.0
# 19         Yoga Mat       2.0
# 14       Smartphone       2.0
# 12     Office Chair       2.0
# 3            Camera       1.0
# 0   Air Conditioner       1.0
# 2         Bookshelf       1.0
# 7   Electric Kettle       1.0
# 4      Coffee Maker       1.0

# %%
revenue_by_product = order_data.groupby('product_name').agg({'total_price': 'sum'}).reset_index()
print(revenue_by_product)

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(revenue_by_product['product_name'], revenue_by_product['total_price'], color='lightgreen')
plt.title('Total Revenue by Product')
plt.xlabel('Product Name')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#        product_name  total_price
# 0   Air Conditioner        850.0
# 1           Blender        180.0
# 2         Bookshelf        180.0
# 3            Camera        650.0
# 4      Coffee Maker        110.0
# 5         Desk Lamp         35.0
# 6      Dining Table        280.0
# 7   Electric Kettle         55.0
# 8        Headphones        130.0
# 9            LED TV        450.0
# 10           Laptop       1100.0
# 11   Microwave Oven        540.0
# 12     Office Chair        260.0
# 13     Refrigerator       1100.0
# 14       Smartphone       1500.0
# 15       Smartwatch        230.0
# 16             Sofa        550.0
# 17        Treadmill        750.0
# 18  Washing Machine        650.0
# 19         Yoga Mat         50.0

# %%
revenue_by_category = order_data.merge(product_data[['product_id', 'category']], on='product_id')
revenue_by_category = revenue_by_category.groupby('category').agg({'total_price': 'sum'}).reset_index()
revenue_by_category['percentage'] = (revenue_by_category['total_price'] / revenue_by_category['total_price'].sum()) * 100
print(revenue_by_category)

# Plotting
plt.figure(figsize=(10, 7))
plt.pie(revenue_by_category['percentage'], labels=revenue_by_category['category'], autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Total Revenue Percentage by Product Category')
plt.show()
# Out:
#             category  total_price  percentage
# 0        Electronics       4060.0   42.072539
# 1          Furniture       1305.0   13.523316
# 2    Home Appliances       3485.0   36.113990
# 3  Sports & Outdoors        800.0    8.290155

# %%
# Query to get total revenue from all orders
cr.execute('''
    SELECT SUM(total_price) AS total_revenue
    FROM order_details
''')
# Fetch the result
result = cr.fetchone()

# Extract total revenue from the result
total_revenue = result[0]

# Create a DataFrame for plotting
data = {'Total Revenue': [total_revenue]}
df = pd.DataFrame(data)

# Create and display a bar graph
plt.figure(figsize=(8, 6))
plt.bar(df.index, df['Total Revenue'], color='skyblue')
plt.title('Total Revenue Generated from All Orders')
plt.xlabel('Total Revenue')
plt.ylabel('Amount ($)')
plt.xticks(df.index, ['Total Revenue'])
plt.tight_layout()
plt.show()

# %%
# Query data to get product details with original and selling prices
cr.execute('''
    SELECT product_id, product_name, original_price, selling_price
    FROM product
''')
product_data = pd.DataFrame(cr.fetchall(), columns=['product_id', 'product_name', 'original_price', 'selling_price'])

# Calculate profit for each product
product_data['profit'] = product_data['selling_price'] - product_data['original_price']

# Sort products by profit in descending order
product_data = product_data.sort_values(by='profit', ascending=False)

# Select top 10 most profitable products
top_10_products = product_data.head(10)

# Plotting the bar chart for top 10 products
plt.figure(figsize=(12, 8))
plt.bar(top_10_products['product_name'], top_10_products['profit'], color='lightcoral')
plt.title('Top 10 Most Profitable Products Based on Price Difference')
plt.xlabel('Product Name')
plt.ylabel('Profit ($)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# Display the top 10 profitable products data
print(top_10_products[['product_name', 'profit']])
# Out:
#        product_name  profit
# 13        Desk Lamp    -5.0
# 18         Yoga Mat    -5.0
# 11  Electric Kettle    -5.0
# 10          Blender   -10.0
# 12     Coffee Maker   -10.0
# 14        Bookshelf   -20.0
# 5    Microwave Oven   -20.0
# 2        Headphones   -20.0
# 16       Smartwatch   -20.0
# 8      Office Chair   -20.0

# %%
# Query data to get total quantity ordered per product
cr.execute('''
    SELECT p.product_name, SUM(od.quantity) AS total_quantity
    FROM order_details od
    JOIN product p ON od.product_id = p.product_id
    GROUP BY p.product_name
    ORDER BY total_quantity DESC
''')
quantity_data = pd.DataFrame(cr.fetchall(), columns=['product_name', 'total_quantity'])

# Identify products with highest and lowest order quantities
highest_quantity_product = quantity_data.iloc[0]
lowest_quantity_product = quantity_data.iloc[-1]

# Prepare data for the bar chart
chart_data = pd.DataFrame({
    'product_name': [highest_quantity_product['product_name'], lowest_quantity_product['product_name']],
    'total_quantity': [highest_quantity_product['total_quantity'], lowest_quantity_product['total_quantity']]
})

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(chart_data['product_name'], chart_data['total_quantity'], color=['lightgreen', 'pink'])
plt.title('Product Names with Highest and Lowest Order Quantities')
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Ordered')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

# Display the chart
plt.show()

# Display the quantities data
print(chart_data)
# Out:
#      product_name  total_quantity
# 0  Microwave Oven             3.0
# 1       Treadmill             1.0

# %%
# Aggregate total quantity ordered by each customer
customer_quantity = order_data.groupby('customer_id').agg({'quantity': 'sum'}).reset_index()

# Merge with customer names to get names
customer_quantity = customer_quantity.merge(customer_data[['customer_id', 'name']], on='customer_id')

# Find the maximum and minimum quantities
max_quantity = customer_quantity['quantity'].max()
min_quantity = customer_quantity['quantity'].min()

# Filter rows for the highest and lowest order quantities
highest_order_customer = customer_quantity[customer_quantity['quantity'] == max_quantity].iloc[0]
lowest_order_customer = customer_quantity[customer_quantity['quantity'] == min_quantity].iloc[0]

# Extract customer names and quantities
highest_customer_name = highest_order_customer['name']
lowest_customer_name = lowest_order_customer['name']

# Data for plotting
customers = [highest_customer_name, lowest_customer_name]
quantities = [highest_order_customer['quantity'], lowest_order_customer['quantity']]

# Create bar plot
plt.figure(figsize=(10, 6))
plt.bar(customers, quantities, color=['lightsalmon', 'pink'])
plt.title('Highest and Lowest Order Quantities by Customer')
plt.xlabel('Customer Name')
plt.ylabel('Total Quantity Ordered')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Query data to get counts of orders by payment mode
cr.execute('''
    SELECT payment_mode, COUNT(*) AS order_count
    FROM order_details
    GROUP BY payment_mode
    ORDER BY order_count DESC
''')
payment_mode_data = pd.DataFrame(cr.fetchall(), columns=['payment_mode', 'order_count'])


# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(payment_mode_data['payment_mode'], payment_mode_data['order_count'], color=sns.color_palette('pastel'))
plt.title('Most Preferred Payment Modes')
plt.xlabel('Payment Mode')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

# Display the chart
plt.show()

# Display the payment mode data
print(payment_mode_data)
# Out:
#   payment_mode  order_count
# 0  Credit Card           10
# 1       PayPal            5
# 2   Debit Card            5

# %%
# Convert 'order_date' to datetime format
order_data['order_date'] = pd.to_datetime(order_data['order_date'])

# Extract month and year from 'order_date'
order_data['year_month'] = order_data['order_date'].dt.to_period('M')

# Aggregate total sales by month
monthly_sales = order_data.groupby('year_month').agg({'total_price': 'sum'}).reset_index()

# Convert 'year_month' back to datetime for plotting
monthly_sales['year_month'] = monthly_sales['year_month'].dt.to_timestamp()

# Plotting the results
plt.figure(figsize=(12, 8))
sns.barplot(x='year_month', y='total_price', data=monthly_sales, color='lightblue')
plt.title('Month-Wise Total Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Analyze the distribution of customers across cities
city_distribution = customer_data['city'].value_counts().reset_index()
city_distribution.columns = ['city', 'customer_count']

# Display the DataFrame
print(city_distribution)
# Out:
#            city  customer_count
# 0       Chicago               5
# 1      New York               4
# 2       Houston               4
# 3   Los Angeles               3
# 4       Phoenix               2
# 5  Philadelphia               1
# 6   San Antonio               1

# %%
# Create a bar plot for city distribution
plt.figure(figsize=(12, 8))
sns.barplot(x='customer_count', y='city', data=city_distribution, palette='viridis',hue='city')

# Add labels and title
plt.xlabel('Number of Customers')
plt.ylabel('City')
plt.title('Distribution of Customers Across Different Cities')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Merge order_data with product_data to get product details
order_product_data = order_data.merge(product_data, on='product_id')

# Merge with customer_data to get city details
order_product_city_data = order_product_data.merge(customer_data, on='customer_id')
order_product_data.head()

# Aggregate total quantity of each product in each city
product_city_quantity = order_product_city_data.groupby(['city', 'product_name']).agg({'quantity': 'sum'}).reset_index()

# Aggregate total quantity of each category in each city
category_city_quantity = order_product_city_data.groupby(['city', 'category']).agg({'quantity': 'sum'}).reset_index()

# Pivot the data for the heatmap
category_heatmap_data = category_city_quantity.pivot(index='city', columns='category', values='quantity').fillna(0)

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(category_heatmap_data, cmap='viridis', annot=True, fmt='g')
plt.title('Category Popularity Heatmap by City')
plt.xlabel('Category')
plt.ylabel('City')
plt.tight_layout()
plt.show()

# %%
# Ensure that 'product_id' columns are in the correct format for merging
order_data['product_id'] = order_data['product_id'].astype(str)
product_data['product_id'] = product_data['product_id'].astype(str)

# Merge order_data with product_data to get product details
order_product_data = order_data.merge(product_data, on='product_id')

# Aggregate total quantity of each product
product_sales = order_product_data.groupby('product_name').agg({'quantity': 'sum'}).reset_index()

# Sort the products by total quantity in descending order
best_selling_products = product_sales.sort_values(by='quantity', ascending=False)

# Select the top 10 best-selling products
top_10_products = best_selling_products.head(10)

# Print the top 10 best-selling products
print("Top 10 Best-Selling Products:")
print(top_10_products)

# Optional: Plotting the results
plt.figure(figsize=(10, 6))
sns.barplot(x='quantity', y='product_name', data=top_10_products, palette='pastel',hue ='quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')
plt.title('Top 10 Best-Selling Products')
plt.tight_layout()
plt.show()
# Out:
# Top 10 Best-Selling Products:
#        product_name  quantity
# 11   Microwave Oven       3.0
# 1           Blender       2.0
# 19         Yoga Mat       2.0
# 14       Smartphone       2.0
# 12     Office Chair       2.0
# 3            Camera       1.0
# 0   Air Conditioner       1.0
# 2         Bookshelf       1.0
# 7   Electric Kettle       1.0
# 4      Coffee Maker       1.0

# %%
# Ensure that 'product_id' columns are in the correct format for merging
order_data['product_id'] = order_data['product_id'].astype(str)
product_data['product_id'] = product_data['product_id'].astype(str)

# Merge order_data with product_data to get product details
order_product_data = order_data.merge(product_data, on='product_id')

# Aggregate total quantity of each product
product_sales = order_product_data.groupby('product_name').agg({'quantity': 'sum'}).reset_index()

# Sort the products by total quantity in ascending order to find slow-moving products
slow_moving_products = product_sales.sort_values(by='quantity').head(10)

# Print the top 10 slow-moving products
print("Top 10 Slow-Moving Products:")
print(slow_moving_products)

# Optional: Plotting the top 10 slow-moving products
plt.figure(figsize=(10, 6))
sns.barplot(x='product_name', y='quantity', data=slow_moving_products, palette='viridis',hue = 'quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')
plt.title('Top 10 Slow-Moving Products')
plt.tight_layout()
plt.show()
# Out:
# Top 10 Slow-Moving Products:
#        product_name  quantity
# 0   Air Conditioner       1.0
# 2         Bookshelf       1.0
# 3            Camera       1.0
# 4      Coffee Maker       1.0
# 6      Dining Table       1.0
# 5         Desk Lamp       1.0
# 7   Electric Kettle       1.0
# 8        Headphones       1.0
# 15       Smartwatch       1.0
# 9            LED TV       1.0
